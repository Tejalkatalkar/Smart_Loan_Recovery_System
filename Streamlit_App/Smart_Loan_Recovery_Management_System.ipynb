# %% [markdown]
# # Smart_Loan_Recovery_Management_System

# %% [markdown]
# # 1.Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import joblib

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# Metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Reading CSV File
Loan_Data = pd.read_csv('Smart_Loan_Recovery_System.csv')

# %% [markdown]
# ## Preparing the Dataset

# %%
Loan_Data.head()
# Out:
#   Borrower_ID  Age  Gender Employment_Type  Monthly_Income  Num_Dependents  \
# 0       BRW_1   59    Male        Salaried          215422               0
# 1       BRW_2   49  Female        Salaried           60893               0
# 2       BRW_3   35    Male        Salaried          116520               1
# 3       BRW_4   63  Female        Salaried          140818               2
# 4       BRW_5   28    Male        Salaried           76272               1
#
#   Loan_ID  Loan_Amount  Loan_Tenure  Interest_Rate  ... Collateral_Value  \
# 0    LN_1      1445796           60          12.39  ...      1727997.258
# 1    LN_2      1044620           12          13.47  ...      1180032.362
# 2    LN_3      1923410           72           7.74  ...      2622539.931
# 3    LN_4      1811663           36          12.23  ...      1145492.680
# 4    LN_5        88578           48          16.13  ...            0.000
#
#    Outstanding_Loan_Amount  Monthly_EMI  Payment_History Num_Missed_Payments  \
# 0             2.914130e+05      4856.88          On-Time                   0
# 1             6.652042e+05     55433.68          On-Time                   0
# 2             1.031372e+06     14324.61          Delayed                   2
# 3             2.249739e+05      6249.28          On-Time                   1
# 4             3.918989e+04       816.46          On-Time                   1
#
#    Days_Past_Due      Recovery_Status Collection_Attempts  Collection_Method  \
# 0              0  Partially Recovered                   1   Settlement Offer
# 1              0      Fully Recovered                   2   Settlement Offer
# 2            124      Fully Recovered                   2       Legal Notice
# 3             56      Fully Recovered                   2              Calls
# 4             69      Fully Recovered                   0    Debt Collectors
#
#   Legal_Action_Taken
# 0                 No
# 1                 No
# 2                 No
# 3                 No
# 4                 No
#
# [5 rows x 21 columns]

# %%
# Show first 5 rows
Loan_Data.shape
# Out:
# (500, 21)

# %%
# Dataset info
Loan_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Borrower_ID              500 non-null    object
#  1   Age                      500 non-null    int64
#  2   Gender                   500 non-null    object
#  3   Employment_Type          500 non-null    object
#  4   Monthly_Income           500 non-null    int64
#  5   Num_Dependents           500 non-null    int64
#  6   Loan_ID                  500 non-null    object
#  7   Loan_Amount              500 non-null    int64
#  8   Loan_Tenure              500 non-null    int64
#  9   Interest_Rate            500 non-null    float64
#  10  Loan_Type                500 non-null    object
#  11  Collateral_Value         500 non-null    float64
#  12  Outstanding_Loan_Amount  500 non-null    float64
#  13  Monthly_EMI              500 non-null    float64
#  14  Payment_History          500 non-null    object
#  15  Num_Missed_Payments      500 non-null    int64
#  16  Days_Past_Due            500 non-null    int64
#  17  Recovery_Status          500 non-null    object
#  18  Collection_Attempts      500 non-null    int64
#  19  Collection_Method        500 non-null    object
#  20  Legal_Action_Taken       500 non-null    object
# dtypes: float64(4), int64(8), object(9)
# memory usage: 82.2+ KB

# %%
# Summary statistics (numerical columns)
Loan_Data.describe
# Out:
# <bound method NDFrame.describe of     Borrower_ID  Age  Gender Employment_Type  Monthly_Income  Num_Dependents  \
# 0         BRW_1   59    Male        Salaried          215422               0
# 1         BRW_2   49  Female        Salaried           60893               0
# 2         BRW_3   35    Male        Salaried          116520               1
# 3         BRW_4   63  Female        Salaried          140818               2
# 4         BRW_5   28    Male        Salaried           76272               1
# ..          ...  ...     ...             ...             ...             ...
# 495     BRW_496   46  Female        Salaried          248483               1
# 496     BRW_497   30  Female        Salaried          243590               3
# 497     BRW_498   46  Female        Salaried          113864               2
# 498     BRW_499   54    Male        Salaried          158401               2
# 499     BRW_500   61    Male   Self-Employed           40169               1
#
#     Loan_ID  Loan_Amount  Loan_Tenure  Interest_Rate  ... Collateral_Value  \
# 0      LN_1      1445796           60          12.39  ...      1727997.258
# 1      LN_2      1044620           12          13.47  ...      1180032.362
# 2      LN_3      1923410           72           7.74  ...      2622539.931
# 3      LN_4      1811663           36          12.23  ...      1145492.680
# 4      LN_5        88578           48          16.13  ...            0.000
# ..      ...          ...          ...            ...  ...              ...
# 495  LN_496       740796           72          16.59  ...            0.000
# 496  LN_497      1408126           60          11.03  ...            0.000
# 497  LN_498       375203           48           9.16  ...            0.000
# 498  LN_499      1769890           24          11.19  ...      1272774.031
# 499  LN_500       394866           12           9.14  ...            0.000
#
#      Outstanding_Loan_Amount  Monthly_EMI  Payment_History  \
# 0               2.914130e+05      4856.88          On-Time
# 1               6.652042e+05     55433.68          On-Time
# 2               1.031372e+06     14324.61          Delayed
# 3               2.249739e+05      6249.28          On-Time
# 4               3.918989e+04       816.46          On-Time
# ..                       ...          ...              ...
# 495             4.135285e+05      5743.45          Delayed
# 496             3.173740e+05      5289.57          Delayed
# 497             3.300302e+05      6875.63          Delayed
# 498             1.565339e+06     65222.46          On-Time
# 499             1.881581e+05     15679.84          On-Time
#
#     Num_Missed_Payments  Days_Past_Due      Recovery_Status  \
# 0                     0              0  Partially Recovered
# 1                     0              0      Fully Recovered
# 2                     2            124      Fully Recovered
# 3                     1             56      Fully Recovered
# 4                     1             69      Fully Recovered
# ..                  ...            ...                  ...
# 495                   2            169      Fully Recovered
# 496                   2            102  Partially Recovered
# 497                   3            140      Fully Recovered
# 498                   3              9  Partially Recovered
# 499                   1            116          Written Off
#
#     Collection_Attempts  Collection_Method Legal_Action_Taken
# 0                     1   Settlement Offer                 No
# 1                     2   Settlement Offer                 No
# 2                     2       Legal Notice                 No
# 3                     2              Calls                 No
# 4                     0    Debt Collectors                 No
# ..                  ...                ...                ...
# 495                   2   Settlement Offer                 No
# 496                   9   Settlement Offer                 No
# 497                   3   Settlement Offer                 No
# 498                   9              Calls                 No
# 499                   6   Settlement Offer                Yes
#
# [500 rows x 21 columns]>

# %% [markdown]
# ## check the missing values

# %%
#check the missing values
Loan_Data.isnull()
# Out:
#      Borrower_ID    Age  Gender  Employment_Type  Monthly_Income  \
# 0          False  False   False            False           False
# 1          False  False   False            False           False
# 2          False  False   False            False           False
# 3          False  False   False            False           False
# 4          False  False   False            False           False
# ..           ...    ...     ...              ...             ...
# 495        False  False   False            False           False
# 496        False  False   False            False           False
# 497        False  False   False            False           False
# 498        False  False   False            False           False
# 499        False  False   False            False           False
#
#      Num_Dependents  Loan_ID  Loan_Amount  Loan_Tenure  Interest_Rate  ...  \
# 0             False    False        False        False          False  ...
# 1             False    False        False        False          False  ...
# 2             False    False        False        False          False  ...
# 3             False    False        False        False          False  ...
# 4             False    False        False        False          False  ...
# ..              ...      ...          ...          ...            ...  ...
# 495           False    False        False        False          False  ...
# 496           False    False        False        False          False  ...
# 497           False    False        False        False          False  ...
# 498           False    False        False        False          False  ...
# 499           False    False        False        False          False  ...
#
#      Collateral_Value  Outstanding_Loan_Amount  Monthly_EMI  Payment_History  \
# 0               False                    False        False            False
# 1               False                    False        False            False
# 2               False                    False        False            False
# 3               False                    False        False            False
# 4               False                    False        False            False
# ..                ...                      ...          ...              ...
# 495             False                    False        False            False
# 496             False                    False        False            False
# 497             False                    False        False            False
# 498             False                    False        False            False
# 499             False                    False        False            False
#
#      Num_Missed_Payments  Days_Past_Due  Recovery_Status  Collection_Attempts  \
# 0                  False          False            False                False
# 1                  False          False            False                False
# 2                  False          False            False                False
# 3                  False          False            False                False
# 4                  False          False            False                False
# ..                   ...            ...              ...                  ...
# 495                False          False            False                False
# 496                False          False            False                False
# 497                False          False            False                False
# 498                False          False            False                False
# 499                False          False            False                False
#
#      Collection_Method  Legal_Action_Taken
# 0                False               False
# 1                False               False
# 2                False               False
# 3                False               False
# 4                False               False
# ..                 ...                 ...
# 495              False               False
# 496              False               False
# 497              False               False
# 498              False               False
# 499              False               False
#
# [500 rows x 21 columns]

# %% [markdown]
# ### **Conclusion:**
# The results indicate that all 21 features contain zero missing values across all 500 records. This confirms that the dataset is complete, consistent, and does not require any imputation or removal of records due to null entries.

# %%
Loan_Data.isnull().sum()
# Out:
# Borrower_ID                0
# Age                        0
# Gender                     0
# Employment_Type            0
# Monthly_Income             0
# Num_Dependents             0
# Loan_ID                    0
# Loan_Amount                0
# Loan_Tenure                0
# Interest_Rate              0
# Loan_Type                  0
# Collateral_Value           0
# Outstanding_Loan_Amount    0
# Monthly_EMI                0
# Payment_History            0
# Num_Missed_Payments        0
# Days_Past_Due              0
# Recovery_Status            0
# Collection_Attempts        0
# Collection_Method          0
# Legal_Action_Taken         0
# dtype: int64

# %% [markdown]
# ### **Conclusion:**
# The result of Loan_Data.isnull().sum() shows 0 null values across all 21 columns. This indicates that the dataset is complete and contains no missing entries, so no imputation or data cleaning for null values is required.

# %% [markdown]
# ## Creating backup copy()

# %%
Backup = Loan_Data.copy()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Count of borrowers by Gender
Loan_Data["Gender"].value_counts()
# Out:
# Gender
# Male      311
# Female    189
# Name: count, dtype: int64

# %%
# Loan Type distribution
Loan_Data["Loan_Type"].value_counts()
# Out:
# Loan_Type
# Personal    220
# Home        144
# Auto         87
# Business     49
# Name: count, dtype: int64

# %%
# Average Loan Amount by Employment Type
Loan_Data.groupby("Employment_Type")["Loan_Amount"].mean()
# Out:
# Employment_Type
# Business Owner    1.011490e+06
# Salaried          1.023313e+06
# Self-Employed     1.032498e+06
# Name: Loan_Amount, dtype: float64

# %%
Loan_Data["Collection_Method"].unique()
# Out:
# array(['Settlement Offer', 'Legal Notice', 'Calls', 'Debt Collectors'],
#       dtype=object)

# %%
# Select only numeric columns for correlation
numeric_data = Loan_Data.select_dtypes(include=['number'])

# %% [markdown]
# ## Categoriacal plots

# %%
sns.boxplot(x=Loan_Data['Loan_Amount'])
plt.show()

# %% [markdown]
# Observations:
#
# The boxplot shows no extreme outliers, because There are no individual points beyond the whiskers.
#
# The data is fairly evenly distributed between 0 and around 2,000,000.
#
# The median (middle line in the box) is slightly below the center, meaning:More people tend to have slightly higher loan amounts compared to lower amounts.
#
# The whiskers represent the minimum and maximum values within the normal range. Since no dots are outside, there are no detected outliers in this visualization.
#
# the distribution is well-balanced and does not contain any anomalous loan amounts.

# %%
# Calculate counts per age
Age_counts = Loan_Data['Age'].value_counts()

# Get top 10 ages by borrower count
Top_10Borrower_ages = Age_counts.head(10).index.tolist()

# Filter Loan_Data to include only rows with those top 10 ages
top_10_data = Loan_Data[Loan_Data['Age'].isin(Top_10Borrower_ages)]

sns.countplot(x="Age", data=top_10_data, order=Top_10Borrower_ages)
plt.title("Borrower Count by Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Distribution for Borrower Count by Age Chart
#
# The highest borrower count is at age 53, indicating this age group has the most active borrowers.Ages 55 and 46 also have a relatively high number of borrowers, showing a concentration in the mid-40s to mid-50s range.
#
# Borrower counts gradually decrease for other ages, suggesting less borrowing activity among younger and older age groups.
#
# This trend highlights that middle-aged individuals are the primary target audience for loans, likely due to stable employment and higher financial responsibilities.

# %%
sns.countplot(x='Payment_History', hue='Recovery_Status', data=Loan_Data)
plt.title("Payment History vs Recovery Status")
plt.show()

# %% [markdown]
# ### **Conclusion for Payment History vs Recovery Status**
#
# 1. **On-Time Payments:**
#
#    * Highest count of **Fully Recovered** loans.
#    * Indicates that consistent on-time payments strongly correlate with full recovery.
#
# 2. **Delayed Payments:**
#
#    * Significant number of **Partially Recovered** and **Written Off** loans.
#    * Suggests delays increase the risk of incomplete recovery.
#
# 3. **Missed Payments:**
#
#    * Lowest count overall but majority are either **Partially Recovered** or **Written Off**.
#    * Missed payments are a strong indicator of potential loan default.
#    *
# Improving on-time payments through reminders or flexible payment options could significantly reduce defaults and increase full loan recovery.

# %%
# Distribution Analysis
plt.figure(figsize=(8,5))
sns.boxplot(x='Recovery_Status', y='Loan_Amount', data=Loan_Data)
plt.title('Loan Amount vs Recovery Status')
plt.show()

# %% [markdown]
# ### **Conclusion for Loan Amount by Recovery Status (Boxplot)**
#
# 1. **Fully Recovered Loans:**
#
#    * Median loan amount is around **1M**.
#    * Wide range, indicating both small and large loans can be fully recovered.
#
# 2. **Partially Recovered Loans:**
#
#    * Median slightly higher than fully recovered.
#    * More variability, showing inconsistent recovery for mid-to-high loan amounts.
#
# 3. **Written Off Loans:**
#
#    * Median is lower (\~0.8M), but there are extreme outliers at high amounts.
#    * Suggests lower-value loans are more likely to be written off, but even large loans can fail.
#
# Higher loan amounts tend to have better recovery rates, while smaller loans show a higher risk of being written off. Proper risk assessment is crucial before approving smaller loans.

# %%
# Bar plot
plt.figure(figsize=(8,6))
plt.barh(Loan_Data["Age"], Loan_Data["Loan_Amount"], color="skyblue", edgecolor="black")
plt.xlabel("Age")
plt.ylabel("Loan Amount")
plt.title("Loan Amount by Age")
plt.show()

# %% [markdown]
# ### **Conclusion for Loan Amount by Age (Bar Chart)**
#
# 1. **Peak Loan Amounts:**
#
#    * Ages **45–55** show the highest loan amounts, indicating strong borrowing activity in mid-age groups.
#
# 2. **Moderate Borrowing:**
#
#    * Ages **30–44** have moderate loan amounts, suggesting early career borrowers.
#
# 3. **Low Loan Amounts:**
#
#    * Younger (<30) and older (>55) age groups take smaller loans.
#
# 4. **Key Insight:**
#
#    * Mid-aged individuals are the primary loan seekers, likely due to **stable income** and **higher financial commitments**.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(Loan_Data["Outstanding_Loan_Amount"], bins=10, kde=True, color="crimson")
plt.title("Distribution of Outstanding Loan Amount")
plt.xlabel("Outstanding Loan Amount")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### **Conclusion for Distribution of Outstanding Loan Amount**
#
# * Most **outstanding loan amounts** are **low**, concentrated between **0 and 0.25M**.
# * The frequency decreases sharply as the loan amount increases, showing a **right-skewed distribution**.
# * Very **few borrowers** have loans above **1.25M**, indicating **high-value loans are rare**.
# * This suggests most borrowers take **small to medium-sized loans**, likely for manageable repayment.

# %%
# Pie chart for Loan Recovery Status
colors = sns.color_palette("deep", n_colors=len(Loan_Data["Recovery_Status"].value_counts()))
plt.figure(figsize=(7,7))
plt.pie(
    Loan_Data["Recovery_Status"].value_counts(),
    labels=Loan_Data["Recovery_Status"].value_counts().index,
    colors=colors,
    autopct='%1.1f%%',         # Fix autopct format
    startangle=90,              # Start pie chart at 90 degrees
    wedgeprops={'edgecolor': 'black'}
)
plt.title("Outstanding Loan Amount vs Monthly EMI", fontsize=14)
plt.legend(title="Recovery Status", loc="best")
plt.show()

# %% [markdown]
# ### **Conclusion for Loan Recovery Status Pie Chart**
#
# * **Fully Recovered:** 59.2% of loans are fully recovered, indicating a strong repayment trend.
# * **Partially Recovered:** 30.8% are partially recovered, suggesting some repayment challenges.
# * **Written Off:** 10% are written off, representing default cases.
#
# * *Overall, most loans are successfully recovered, but 40.8% need attention for better recovery strategies.*

# %%
# Create subplots (1 row, 2 columns)
plt.figure(figsize=(14, 6))

# --- Plot 1 ---
plt.subplot(1, 2, 1)
plt.scatter(Loan_Data["Outstanding_Loan_Amount"], Loan_Data["Monthly_EMI"], color="blue")
plt.title("Outstanding Loan Amount vs Monthly EMI")
plt.xlabel("Outstanding Loan Amount")
plt.ylabel("Monthly EMI")

# --- Plot 2 ---
plt.subplot(1, 2, 2)
sns.scatterplot(x="Monthly_Income", y="Loan_Amount", hue="Loan_Type", data=Loan_Data, s=70)
plt.title("Loan Amount vs Monthly Income by Loan Type")
plt.xlabel("Monthly Income")
plt.ylabel("Loan Amount")

# Show plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Conclusion for the Two Scatter Plots**
#
# 1. **Outstanding Loan Amount vs Monthly EMI**
#    There is a **positive correlation** between outstanding loan amount and monthly EMI, indicating that **higher loan amounts lead to higher EMIs**.
#    A few points are scattered far apart, showing the presence of **high-value loans with very high EMIs**.
#
# 2. **Loan Amount vs Monthly Income by Loan Type**
#    Loan amounts are **spread across all income ranges**, with no clear clustering.
#    Different loan types (Home, Auto, Personal, Business) are **evenly distributed**, suggesting that **income is not the sole factor influencing loan type selection**.

# %%
# Correlation matrix
numeric_data.corr()
# Out:
#                               Age  Monthly_Income  Num_Dependents  \
# Age                      1.000000        0.015005        0.005962
# Monthly_Income           0.015005        1.000000        0.097276
# Num_Dependents           0.005962        0.097276        1.000000
# Loan_Amount             -0.012346        0.002110       -0.040438
# Loan_Tenure             -0.081484        0.092388       -0.006212
# Interest_Rate            0.079375        0.081852        0.051468
# Collateral_Value        -0.047526        0.025040        0.010134
# Outstanding_Loan_Amount  0.036566        0.029607       -0.034971
# Monthly_EMI              0.071853       -0.027688       -0.027397
# Num_Missed_Payments     -0.037805        0.039656        0.085348
# Days_Past_Due            0.048016        0.016928        0.065222
# Collection_Attempts      0.028419        0.042408       -0.019939
#
#                          Loan_Amount  Loan_Tenure  Interest_Rate  \
# Age                        -0.012346    -0.081484       0.079375
# Monthly_Income              0.002110     0.092388       0.081852
# Num_Dependents             -0.040438    -0.006212       0.051468
# Loan_Amount                 1.000000     0.000131      -0.088530
# Loan_Tenure                 0.000131     1.000000      -0.002032
# Interest_Rate              -0.088530    -0.002032       1.000000
# Collateral_Value            0.500603    -0.023532       0.012073
# Outstanding_Loan_Amount     0.751261     0.004416      -0.052589
# Monthly_EMI                 0.513592    -0.494992      -0.069612
# Num_Missed_Payments        -0.004125    -0.021841      -0.042725
# Days_Past_Due               0.004360     0.028505       0.038524
# Collection_Attempts         0.009199    -0.016437      -0.030032
#
#                          Collateral_Value  Outstanding_Loan_Amount  \
# Age                             -0.047526                 0.036566
# Monthly_Income                   0.025040                 0.029607
# Num_Dependents                   0.010134                -0.034971
# Loan_Amount                      0.500603                 0.751261
# Loan_Tenure                     -0.023532                 0.004416
# Interest_Rate                    0.012073                -0.052589
# Collateral_Value                 1.000000                 0.369952
# Outstanding_Loan_Amount          0.369952                 1.000000
# Monthly_EMI                      0.264826                 0.689876
# Num_Missed_Payments              0.046915                 0.051649
# Days_Past_Due                   -0.008893                 0.041214
# Collection_Attempts             -0.058284                -0.010322
#
#                          Monthly_EMI  Num_Missed_Payments  Days_Past_Due  \
# Age                         0.071853            -0.037805       0.048016
# Monthly_Income             -0.027688             0.039656       0.016928
# Num_Dependents             -0.027397             0.085348       0.065222
# Loan_Amount                 0.513592            -0.004125       0.004360
# Loan_Tenure                -0.494992            -0.021841       0.028505
# Interest_Rate              -0.069612            -0.042725       0.038524
# Collateral_Value            0.264826             0.046915      -0.008893
# Outstanding_Loan_Amount     0.689876             0.051649       0.041214
# Monthly_EMI                 1.000000             0.027846       0.037874
# Num_Missed_Payments         0.027846             1.000000       0.343797
# Days_Past_Due               0.037874             0.343797       1.000000
# Collection_Attempts         0.030343             0.033484       0.062066
#
#                          Collection_Attempts
# Age                                 0.028419
# Monthly_Income                      0.042408
# Num_Dependents                     -0.019939
# Loan_Amount                         0.009199
# Loan_Tenure                        -0.016437
# Interest_Rate                      -0.030032
# Collateral_Value                   -0.058284
# Outstanding_Loan_Amount            -0.010322
# Monthly_EMI                         0.030343
# Num_Missed_Payments                 0.033484
# Days_Past_Due                       0.062066
# Collection_Attempts                 1.000000

# %%
# Select numeric columns
numeric_data = Loan_Data.select_dtypes(include=['float64', 'int64'])

# Compute correlation matrix
corr_matrix = numeric_data.corr()

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(
    data=corr_matrix, annot=True,fmt=".2f", cmap="coolwarm",linewidths=0.5)
plt.title("Correlation Heatmap of Loan Features")
plt.show()

# %% [markdown]
# ### **Conclusion from Correlation Heatmap**
# * **Strong Positive Correlations**
#
# * **Loan Amount & Outstanding Loan Amount (0.75)**:Higher loan amounts are strongly associated with higher outstanding balances.
#
# * **Outstanding Loan Amount & Monthly EMI (0.69)**:Larger outstanding loans result in higher monthly EMIs.
#
# * **Collateral Value & Loan Amount (0.50)**:Loans with higher amounts tend to have higher collateral values.

# %%
Loan_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Borrower_ID              500 non-null    object
#  1   Age                      500 non-null    int64
#  2   Gender                   500 non-null    object
#  3   Employment_Type          500 non-null    object
#  4   Monthly_Income           500 non-null    int64
#  5   Num_Dependents           500 non-null    int64
#  6   Loan_ID                  500 non-null    object
#  7   Loan_Amount              500 non-null    int64
#  8   Loan_Tenure              500 non-null    int64
#  9   Interest_Rate            500 non-null    float64
#  10  Loan_Type                500 non-null    object
#  11  Collateral_Value         500 non-null    float64
#  12  Outstanding_Loan_Amount  500 non-null    float64
#  13  Monthly_EMI              500 non-null    float64
#  14  Payment_History          500 non-null    object
#  15  Num_Missed_Payments      500 non-null    int64
#  16  Days_Past_Due            500 non-null    int64
#  17  Recovery_Status          500 non-null    object
#  18  Collection_Attempts      500 non-null    int64
#  19  Collection_Method        500 non-null    object
#  20  Legal_Action_Taken       500 non-null    object
# dtypes: float64(4), int64(8), object(9)
# memory usage: 82.2+ KB

# %%
Loan_Data.describe()
# Out:
#               Age  Monthly_Income  Num_Dependents   Loan_Amount  Loan_Tenure  \
# count  500.000000      500.000000      500.000000  5.000000e+02    500.00000
# mean    43.116000   134829.920000        1.476000  1.024907e+06     46.10400
# std     12.733217    68969.356746        1.145447  5.907556e+05     18.23706
# min     21.000000    15207.000000        0.000000  5.413800e+04     12.00000
# 25%     32.000000    76343.250000        0.000000  4.629848e+05     36.00000
# 50%     44.000000   134929.500000        1.000000  9.971240e+05     48.00000
# 75%     53.000000   193086.250000        3.000000  1.557952e+06     60.00000
# max     64.000000   249746.000000        3.000000  1.995325e+06     72.00000
#
#        Interest_Rate  Collateral_Value  Outstanding_Loan_Amount  \
# count     500.000000      5.000000e+02             5.000000e+02
# mean       11.192820      6.032240e+05             5.627260e+05
# std         3.775209      7.457131e+05             4.723581e+05
# min         5.020000      0.000000e+00             1.571283e+04
# 25%         7.907500      0.000000e+00             1.822072e+05
# 50%        10.915000      2.327684e+05             4.133240e+05
# 75%        14.577500      1.111106e+06             8.324787e+05
# max        17.970000      2.744395e+06             1.932396e+06
#
#          Monthly_EMI  Num_Missed_Payments  Days_Past_Due  Collection_Attempts
# count     500.000000           500.000000     500.000000           500.000000
# mean    15861.536020             1.912000      70.678000             3.000000
# std     18709.231315             2.110252      60.211038             2.807805
# min       261.880000             0.000000       0.000000             0.000000
# 25%      4039.097500             1.000000       4.000000             1.000000
# 50%      9330.170000             2.000000      66.500000             2.000000
# 75%     20439.485000             3.000000     122.250000             4.000000
# max    127849.230000            12.000000     180.000000            10.000000

# %% [markdown]
# # Quality of the data

# %%
Loan_Data
# Out:
#     Borrower_ID  Age  Gender Employment_Type  Monthly_Income  Num_Dependents  \
# 0         BRW_1   59    Male        Salaried          215422               0
# 1         BRW_2   49  Female        Salaried           60893               0
# 2         BRW_3   35    Male        Salaried          116520               1
# 3         BRW_4   63  Female        Salaried          140818               2
# 4         BRW_5   28    Male        Salaried           76272               1
# ..          ...  ...     ...             ...             ...             ...
# 495     BRW_496   46  Female        Salaried          248483               1
# 496     BRW_497   30  Female        Salaried          243590               3
# 497     BRW_498   46  Female        Salaried          113864               2
# 498     BRW_499   54    Male        Salaried          158401               2
# 499     BRW_500   61    Male   Self-Employed           40169               1
#
#     Loan_ID  Loan_Amount  Loan_Tenure  Interest_Rate  ... Collateral_Value  \
# 0      LN_1      1445796           60          12.39  ...      1727997.258
# 1      LN_2      1044620           12          13.47  ...      1180032.362
# 2      LN_3      1923410           72           7.74  ...      2622539.931
# 3      LN_4      1811663           36          12.23  ...      1145492.680
# 4      LN_5        88578           48          16.13  ...            0.000
# ..      ...          ...          ...            ...  ...              ...
# 495  LN_496       740796           72          16.59  ...            0.000
# 496  LN_497      1408126           60          11.03  ...            0.000
# 497  LN_498       375203           48           9.16  ...            0.000
# 498  LN_499      1769890           24          11.19  ...      1272774.031
# 499  LN_500       394866           12           9.14  ...            0.000
#
#      Outstanding_Loan_Amount  Monthly_EMI  Payment_History  \
# 0               2.914130e+05      4856.88          On-Time
# 1               6.652042e+05     55433.68          On-Time
# 2               1.031372e+06     14324.61          Delayed
# 3               2.249739e+05      6249.28          On-Time
# 4               3.918989e+04       816.46          On-Time
# ..                       ...          ...              ...
# 495             4.135285e+05      5743.45          Delayed
# 496             3.173740e+05      5289.57          Delayed
# 497             3.300302e+05      6875.63          Delayed
# 498             1.565339e+06     65222.46          On-Time
# 499             1.881581e+05     15679.84          On-Time
#
#     Num_Missed_Payments  Days_Past_Due      Recovery_Status  \
# 0                     0              0  Partially Recovered
# 1                     0              0      Fully Recovered
# 2                     2            124      Fully Recovered
# 3                     1             56      Fully Recovered
# 4                     1             69      Fully Recovered
# ..                  ...            ...                  ...
# 495                   2            169      Fully Recovered
# 496                   2            102  Partially Recovered
# 497                   3            140      Fully Recovered
# 498                   3              9  Partially Recovered
# 499                   1            116          Written Off
#
#     Collection_Attempts  Collection_Method Legal_Action_Taken
# 0                     1   Settlement Offer                 No
# 1                     2   Settlement Offer                 No
# 2                     2       Legal Notice                 No
# 3                     2              Calls                 No
# 4                     0    Debt Collectors                 No
# ..                  ...                ...                ...
# 495                   2   Settlement Offer                 No
# 496                   9   Settlement Offer                 No
# 497                   3   Settlement Offer                 No
# 498                   9              Calls                 No
# 499                   6   Settlement Offer                Yes
#
# [500 rows x 21 columns]

# %%
print(Loan_Data.columns)
# Out:
# Index(['Borrower_ID', 'Age', 'Gender', 'Employment_Type', 'Monthly_Income',
#        'Num_Dependents', 'Loan_ID', 'Loan_Amount', 'Loan_Tenure',
#        'Interest_Rate', 'Loan_Type', 'Collateral_Value',
#        'Outstanding_Loan_Amount', 'Monthly_EMI', 'Payment_History',
#        'Num_Missed_Payments', 'Days_Past_Due', 'Recovery_Status',
#        'Collection_Attempts', 'Collection_Method', 'Legal_Action_Taken'],
#       dtype='object')

# %%
plt.figure(figsize=(15,20))

# 1
plt.subplot(2,2,1)
sns.boxplot(
    x="Recovery_Status", 
    y="Monthly_Income", 
    data=Loan_Data, 
    hue="Recovery_Status",
    palette="mako",
    legend=False
)
plt.title("Monthly Income vs Recovery Status")
plt.legend([],[], frameon=False)

# 2
plt.subplot(2,2,2)
sns.boxplot(
    x="Recovery_Status", 
    y="Loan_Amount", 
    data=Loan_Data, 
    hue="Recovery_Status",
    palette="mako",
    legend=False
)
plt.title("Loan Amount vs Recovery Status")
plt.legend([],[], frameon=False)

# 3
plt.subplot(2,2,3)
sns.boxplot(
    x="Recovery_Status", 
    y="Outstanding_Loan_Amount", 
    data=Loan_Data, 
    hue="Recovery_Status",
    palette="rocket",
    legend=False
)
plt.title("Outstanding Loan Amount vs Recovery Status")
plt.legend([],[], frameon=False)

# 4
plt.subplot(2,2,4)
sns.boxplot(
    x="Recovery_Status", 
    y="Loan_Tenure", 
    data=Loan_Data, 
    hue="Recovery_Status",
    palette="rocket",
    legend=False
)
plt.title("Loan Tenure vs Recovery Status")
plt.legend([],[], frameon=False)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Split data into training and testing sets

# %%
Loan_Data['Recovery_Status'].unique()
# Out:
# array(['Partially Recovered', 'Fully Recovered', 'Written Off'],
#       dtype=object)

# %%
# Create binary target column
Loan_Data["Recovered"] = Loan_Data["Recovery_Status"].map({
    "Fully Recovered": 1,
    "Partially Recovered": 0,
    "Written Off": 0
})

print(Loan_Data["Recovered"].value_counts())
# Out:
# Recovered
# 1    296
# 0    204
# Name: count, dtype: int64

# %%
# Separate features and target
X = Loan_Data.drop(["Recovery_Status", "Recovered","Loan_ID", "Borrower_ID"], axis=1) # Features
y = Loan_Data["Recovered"]                                   # Target (Yes/No)a

# %%
# Check
print("Features (x):")
print(X.head())
print("\nTarget (y):")
print(y.head())
# Out:
# Features (x):
#    Age  Gender Employment_Type  Monthly_Income  Num_Dependents  Loan_Amount  \
# 0   59    Male        Salaried          215422               0      1445796
# 1   49  Female        Salaried           60893               0      1044620
# 2   35    Male        Salaried          116520               1      1923410
# 3   63  Female        Salaried          140818               2      1811663
# 4   28    Male        Salaried           76272               1        88578
#
#    Loan_Tenure  Interest_Rate Loan_Type  Collateral_Value  \
# 0           60          12.39      Home       1727997.258
# 1           12          13.47      Auto       1180032.362
# 2           72           7.74      Home       2622539.931
# 3           36          12.23      Home       1145492.680
# 4           48          16.13  Personal             0.000
#
#    Outstanding_Loan_Amount  Monthly_EMI Payment_History  Num_Missed_Payments  \
# 0             2.914130e+05      4856.88         On-Time                    0
# 1             6.652042e+05     55433.68         On-Time                    0
# 2             1.031372e+06     14324.61         Delayed                    2
# 3             2.249739e+05      6249.28         On-Time                    1
# 4             3.918989e+04       816.46         On-Time                    1
#
#    Days_Past_Due  Collection_Attempts Collection_Method Legal_Action_Taken
# 0              0                    1  Settlement Offer                 No
# 1              0                    2  Settlement Offer                 No
# 2            124                    2      Legal Notice                 No
# 3             56                    2             Calls                 No
# 4             69                    0   Debt Collectors                 No
#
# Target (y):
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Recovered, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
import joblib

le = LabelEncoder()
y_encoded = le.fit_transform(y)  # 'No'->0, 'Yes'->1
joblib.dump(le, "target_encoder.pkl")
# Out:
# ['target_encoder.pkl']

# %% [markdown]
# # Split the data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)

# %%
# 3. Identify column types
numeric_cols = X.select_dtypes(include='number').columns
categorical_cols = X.select_dtypes(include='object').columns

# %% [markdown]
# # Preprocessing Pipeline

# %%
preprocessor = ColumnTransformer([
    ("num", Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ]), numeric_cols),

    ("cat", Pipeline([
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("encoder", OneHotEncoder(handle_unknown="ignore"))
    ]), categorical_cols)
])

# %%
#Check first 5 rows of training features
print(X_train.head())
# Out:
#      Age  Gender Employment_Type  Monthly_Income  Num_Dependents  Loan_Amount  \
# 249   62    Male        Salaried           22151               0      1995049
# 433   49  Female        Salaried           61479               1      1452549
# 19    64  Female   Self-Employed           48397               1      1149577
# 322   49    Male        Salaried          103920               3       134381
# 332   41    Male   Self-Employed          240952               3       303091
#
#      Loan_Tenure  Interest_Rate Loan_Type  Collateral_Value  \
# 249           36           8.96  Personal             0.000
# 433           72          15.92      Auto       1573296.237
# 19            12          12.76      Auto       1106575.402
# 322           24          16.84  Personal             0.000
# 332           36          15.44  Personal             0.000
#
#      Outstanding_Loan_Amount  Monthly_EMI Payment_History  \
# 249             1.529768e+06     42493.57         Delayed
# 433             1.355584e+06     18827.55         On-Time
# 19              1.378081e+05     11484.01         On-Time
# 322             1.978539e+04       824.39         On-Time
# 332             5.191701e+04      1442.14         On-Time
#
#      Num_Missed_Payments  Days_Past_Due  Collection_Attempts  \
# 249                    1            140                    1
# 433                    3            119                    1
# 19                     2             42                    2
# 322                    2             13                    3
# 332                    1            147                    0
#
#     Collection_Method Legal_Action_Taken
# 249      Legal Notice                 No
# 433  Settlement Offer                 No
# 19    Debt Collectors                 No
# 322      Legal Notice                 No
# 332      Legal Notice                 No

# %%
# Check first 5 rows of test features
print(X_test.head())
# Out:
#      Age  Gender Employment_Type  Monthly_Income  Num_Dependents  Loan_Amount  \
# 361   55  Female        Salaried          141888               0      1753834
# 73    28    Male        Salaried           79178               3      1482769
# 374   35  Female   Self-Employed          237374               0       846710
# 155   22  Female   Self-Employed          133516               3      1917306
# 104   61  Female        Salaried          150542               2      1190844
#
#      Loan_Tenure  Interest_Rate Loan_Type  Collateral_Value  \
# 361           72          17.81      Auto       1601438.800
# 73            72           6.39  Personal             0.000
# 374           36          12.84      Home       1037462.827
# 155           24           7.66  Personal             0.000
# 104           12          15.14  Personal             0.000
#
#      Outstanding_Loan_Amount  Monthly_EMI Payment_History  \
# 361             1.475467e+06     20492.60         On-Time
# 73              3.812657e+05      5295.36         On-Time
# 374             6.279152e+05     17442.09         On-Time
# 155             1.374051e+06     57252.12          Missed
# 104             1.015521e+06     84626.74         Delayed
#
#      Num_Missed_Payments  Days_Past_Due  Collection_Attempts  \
# 361                    3             78                    2
# 73                     2              7                    3
# 374                    0              0                    0
# 155                    1            166                    2
# 104                    3            147                   10
#
#     Collection_Method Legal_Action_Taken
# 361   Debt Collectors                 No
# 73              Calls                 No
# 374      Legal Notice                 No
# 155   Debt Collectors                 No
# 104      Legal Notice                 No

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Logistic Regression pipeline
log_reg_clf = Pipeline([
    ("preprocess", preprocessor),
    ("model", LogisticRegression(max_iter=1000))
])

# Train the model
log_reg_clf.fit(X_train, y_train)

# Predict
y_pred_log = log_reg_clf.predict(X_test)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred_log))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_log))
print("\nClassification Report:\n", classification_report(y_test, y_pred_log))
# Out:
# Accuracy: 0.79
#
# Confusion Matrix:
#  [[31 13]
#  [ 8 48]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.70      0.75        44
#            1       0.79      0.86      0.82        56
#
#     accuracy                           0.79       100
#    macro avg       0.79      0.78      0.78       100
# weighted avg       0.79      0.79      0.79       100

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_log )
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Logistic Regression Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Decision Tree pipeline
dt_clf = Pipeline([
    ("preprocess", preprocessor), ("model", DecisionTreeClassifier (criterion='gini', max_depth=5, min_samples_split=10,random_state=42
    ))
])

# Train model
dt_clf.fit(X_train, y_train)

# Predict
y_pred_dt = dt_clf.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_dt))

# Confusion Matrix & Report
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
print("\nClassification Report:\n", classification_report(y_test, y_pred_dt, zero_division=0))
# Out:
# Accuracy: 0.88
#
# Confusion Matrix:
#  [[32 12]
#  [ 0 56]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.73      0.84        44
#            1       0.82      1.00      0.90        56
#
#     accuracy                           0.88       100
#    macro avg       0.91      0.86      0.87       100
# weighted avg       0.90      0.88      0.88       100

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline

# Create the SVM pipeline
svc_clf = Pipeline([
    ("preprocess", preprocessor), ("model", SVC(kernel='rbf', probability=True, random_state=42))
])

# Train the model
svc_clf.fit(X_train, y_train)

# Predict
y_pred_svc = svc_clf.predict(X_test)

# Evaluate
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred_svc))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_svc))
print("\nClassification Report:\n", classification_report(y_test, y_pred_svc))
# Out:
# Accuracy: 0.84
#
# Confusion Matrix:
#  [[28 16]
#  [ 0 56]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78        44
#            1       0.78      1.00      0.88        56
#
#     accuracy                           0.84       100
#    macro avg       0.89      0.82      0.83       100
# weighted avg       0.88      0.84      0.83       100

# %% [markdown]
# # XGBoost Classifier

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline

xgb_clf = Pipeline([
    ("preprocess", preprocessor),
    ("model", XGBClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=5,
        subsample=0.8,
        colsample_bytree=0.8,
        eval_metric="logloss",   # IMPORTANT
        random_state=42,
        tree_method="hist"       # Faster + best for CPU
    ))
])
xgb_clf.fit(X_train, y_train)
# Predict
y_pred_xgb = xgb_clf.predict(X_test)
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))
print(confusion_matrix(y_test, y_pred_xgb))
# Out:
# Accuracy: 0.83
#               precision    recall  f1-score   support
#
#            0       0.91      0.68      0.78        44
#            1       0.79      0.95      0.86        56
#
#     accuracy                           0.83       100
#    macro avg       0.85      0.81      0.82       100
# weighted avg       0.84      0.83      0.83       100
#
# [[30 14]
#  [ 3 53]]

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_xgb )
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Logistic Regression Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # LightGBM

# %%
from sklearn.pipeline import Pipeline
from lightgbm import LGBMClassifier

pipeline = Pipeline([
    ("preprocess", preprocessor),
    ("model", LGBMClassifier(verbose=-1, random_state=42))
])
from sklearn.metrics import accuracy_score, classification_report
pipeline.fit(X_train, y_train)

y_pred = pipeline.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.82
#
# Confusion Matrix:
#  [[29 15]
#  [ 3 53]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.66      0.76        44
#            1       0.78      0.95      0.85        56
#
#     accuracy                           0.82       100
#    macro avg       0.84      0.80      0.81       100
# weighted avg       0.84      0.82      0.81       100
# c:\Users\TEJAL KATALKAR\Smart_Loan_Recovery_Management_System___\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Dictionary to store models

# %%
# Dictionary to store models
models = {
    "LogisticRegression": Pipeline([
        ("preprocess", preprocessor),
        ("model", LogisticRegression(max_iter=1000))
    ]),

    "DecisionTree": Pipeline([
        ("preprocess", preprocessor),
        ("model", DecisionTreeClassifier(
            criterion='gini',
            max_depth=5,
            min_samples_split=10,
            random_state=42
        ))
    ]),
    
    "SVC": Pipeline([
        ("preprocess", preprocessor),
        ("model", SVC(kernel='rbf', probability=True, random_state=42))
    ]),

    "XGBoost": Pipeline([
        ("preprocess", preprocessor),
        ("model", XGBClassifier(
            n_estimators=300,
            learning_rate=0.05,
            max_depth=5,
            subsample=0.8,
            colsample_bytree=0.8,
            random_state=42
        ))
    ]),

    "LightGBM": Pipeline([
        ("preprocess", preprocessor),
        ("model", LGBMClassifier(verbose=-1, random_state=42))
    ])
}

# Train all models
for name, model in models.items():
    model.fit(X_train, y_train)
    print(f"{name} trained successfully.")
# Out:
# LogisticRegression trained successfully.
# DecisionTree trained successfully.
# SVC trained successfully.
# XGBoost trained successfully.
# LightGBM trained successfully.

# %%
joblib.dump(models, "all_models.pkl")
print("All models saved successfully!")
# Out:
# All models saved successfully!

# %%
# Load models
loaded_models = joblib.load("all_models.pkl")

# %%
# Save Only Xgboost Model
joblib.dump(xgb_clf, "xgboost_model.pkl")
print(" XGBoost model saved successfully as xgboost_model.pkl")
# Out:
#  XGBoost model saved successfully as xgboost_model.pkl

# %%
input_data = {
    "Age": 28,
    "Gender": "Male",
    "Employment_Type": "Salaried",
    "Annual_Income": 76272,
    "Num_of_Dependents": 1,
    "Loan_Amount": 88578,
    "Loan_Term": 48,
    "Interest_Rate": 16.13,
    "Loan_Purpose": "Personal",
    "Previous_Default": 0,
    "Total_Due": 39189.89,
    "EMI_Amount": 816.46,
    "Payment_Behaviour": "On-Time",
    "Num_Past_Due_Days": 1,
    "Credit_History_Length": 69,
    "Recovery_Status": "Fully Recovered",
    "Num_Recovery_Attempts": 0,
    "Collection_Strategy": "Debt Collectors",
    "Legal_Action": "No"
}


# Placeholder Prediction (replace after loading your model)
prediction = "Fully Recovered"
probability = 0.89

prediction, probability
# Out:
# ('Fully Recovered', 0.89)
